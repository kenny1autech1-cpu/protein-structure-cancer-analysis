# %% [markdown]
# # Notebook 04 — Breast Cancer Gene Expression Analysis
#
# **Goal:** Differential expression analysis of GSE42568 (17 normal vs 121 breast tumour samples). Identify downregulated tumour suppressors including FHL1.
#
# **Dataset:** NCBI GEO — GSE42568, Affymetrix microarray.

# %%
# Coming after AlphaMissense analysis
